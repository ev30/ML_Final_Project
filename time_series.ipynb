# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import dates

# %%
# reading in COVID-19 datasets
dem_df = pd.read_csv('../data/demographics.csv')
eco_df = pd.read_csv('../data/economy.csv')
epi_df = pd.read_csv('../data/epidemiology.csv')
vac_df = pd.read_csv('../data/vaccinations.csv')
idx_df = pd.read_csv('../data/index.csv')

# %%
# viewing datasets
dem_df.head(3)
# Out:
#   location_key  population  population_male  population_female  \
# 0           AD     77265.0          58625.0            55581.0
# 1           AE   9890400.0        6836349.0          3054051.0
# 2           AF  38928341.0       19976265.0         18952076.0
#
#    population_rural  population_urban  population_largest_city  \
# 0            9269.0           67873.0                      NaN
# 1         1290785.0         8479744.0                2833079.0
# 2        28244481.0         9797273.0                4114030.0
#
#    population_clustered  population_density  human_development_index  \
# 0                   NaN             164.394                    0.858
# 1             5914068.0             118.306                    0.863
# 2             4114030.0              59.627                    0.498
#
#    population_age_00_09  population_age_10_19  population_age_20_29  \
# 0                9370.0               12022.0               10727.0
# 1             1011713.0              842991.0             2149343.0
# 2            11088732.0             9821559.0             7035871.0
#
#    population_age_30_39  population_age_40_49  population_age_50_59  \
# 0               12394.0               21001.0               20720.0
# 1             3169314.0             1608109.0              797913.0
# 2             4534646.0             2963459.0             1840198.0
#
#    population_age_60_69  population_age_70_79  population_age_80_and_older
# 0               14433.0                8657.0                       4881.0
# 1              242707.0               55884.0                      12426.0
# 2             1057496.0              480455.0                     105925.0

# %%
eco_df.head(3)
# Out:
#   location_key       gdp_usd  gdp_per_capita_usd  human_capital_index
# 0           AD  3.154058e+09             40886.0                  NaN
# 1           AE  4.211423e+11             43103.0                0.659
# 2           AF  1.910135e+10               502.0                0.389

# %%
epi_df.head(3)
# Out:
#          date location_key  new_confirmed  new_deceased  new_recovered  \
# 0  2020-01-01           AD            0.0           0.0            NaN
# 1  2020-01-02           AD            0.0           0.0            NaN
# 2  2020-01-03           AD            0.0           0.0            NaN
#
#    new_tested  cumulative_confirmed  cumulative_deceased  \
# 0         NaN                   0.0                  0.0
# 1         NaN                   0.0                  0.0
# 2         NaN                   0.0                  0.0
#
#    cumulative_recovered  cumulative_tested
# 0                   NaN                NaN
# 1                   NaN                NaN
# 2                   NaN                NaN

# %%
vac_df.head(3)
# Out:
#          date location_key  new_persons_vaccinated  \
# 0  2021-01-25           AD                     NaN
# 1  2021-02-01           AD                   460.0
# 2  2021-02-10           AD                   255.0
#
#    cumulative_persons_vaccinated  new_persons_fully_vaccinated  \
# 0                          576.0                           NaN
# 1                         1036.0                           NaN
# 2                         1291.0                           NaN
#
#    cumulative_persons_fully_vaccinated  new_vaccine_doses_administered  \
# 0                                  NaN                             NaN
# 1                                  NaN                           460.0
# 2                                  NaN                           255.0
#
#    cumulative_vaccine_doses_administered  new_persons_vaccinated_pfizer  \
# 0                                  576.0                            NaN
# 1                                 1036.0                            NaN
# 2                                 1291.0                            NaN
#
#    cumulative_persons_vaccinated_pfizer  ...  \
# 0                                   NaN  ...
# 1                                   NaN  ...
# 2                                   NaN  ...
#
#    new_persons_fully_vaccinated_janssen  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
#
#    cumulative_persons_fully_vaccinated_janssen  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
#
#    new_vaccine_doses_administered_janssen  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
#
#    cumulative_vaccine_doses_administered_janssen  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
#
#    new_persons_vaccinated_sinovac  total_persons_vaccinated_sinovac  \
# 0                             NaN                               NaN
# 1                             NaN                               NaN
# 2                             NaN                               NaN
#
#    new_persons_fully_vaccinated_sinovac  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
#
#    total_persons_fully_vaccinated_sinovac  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
#
#    new_vaccine_doses_administered_sinovac  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
#
#    total_vaccine_doses_administered_sinovac
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
#
# [3 rows x 32 columns]

# %%
idx_df.head(3)
# Out:
#   location_key                     place_id wikidata_id datacommons_id  \
# 0           AD  ChIJlfCemC71pRIRkn_qeNc-yQc        Q228    country/AND
# 1           AE  ChIJvRKrsd9IXj4RpwoIwFYv0zM        Q878    country/ARE
# 2           AF  ChIJbQL_-LZu0TgReNqWvg1GtfM        Q889    country/AFG
#
#   country_code          country_name subregion1_code subregion1_name  \
# 0           AD               Andorra             NaN             NaN
# 1           AE  United Arab Emirates             NaN             NaN
# 2           AF           Afghanistan             NaN             NaN
#
#   subregion2_code subregion2_name locality_code locality_name  \
# 0             NaN             NaN           NaN           NaN
# 1             NaN             NaN           NaN           NaN
# 2             NaN             NaN           NaN           NaN
#
#   iso_3166_1_alpha_2 iso_3166_1_alpha_3  aggregation_level
# 0                 AD                AND                  0
# 1                 AE                ARE                  0
# 2                 AF                AFG                  0

# %%
idx_df[['country_name']]
# Out:
#                country_name
# 0                   Andorra
# 1      United Arab Emirates
# 2               Afghanistan
# 3               Afghanistan
# 4               Afghanistan
# ...                     ...
# 22958          South Africa
# 22959          South Africa
# 22960          South Africa
# 22961                Zambia
# 22962              Zimbabwe
#
# [22963 rows x 1 columns]

# %%
idx_df.loc[idx_df['country_name'] == 'United States of America']
# Out:
#       location_key                     place_id wikidata_id datacommons_id  \
# 19557           US  ChIJCzYy5IS16lQRQrfeQ5K5Oxw         Q30    country/USA
# 19558        US_AK  ChIJG8CuwJzfAFQRNduKqSde27w        Q797       geoId/02
# 19559  US_AK_02013  ChIJ7a-UgVuW_lYRjTetzbIWL48     Q504371    geoId/02013
# 19560  US_AK_02016  ChIJI9ivbI1Pg1cRg8d4nlGjGVU     Q185533    geoId/02016
# 19561  US_AK_02020  ChIJQT-zBHaRyFYR42iEp1q6fSU      Q39450    geoId/02020
# ...            ...                          ...         ...            ...
# 22837  US_WY_56037  ChIJEVZf4rRTWocRoqATF0f_rnA     Q484194    geoId/56037
# 22838  US_WY_56039  ChIJV3wGpVVrUlMR3m18oGf5rvk     Q488912    geoId/56039
# 22839  US_WY_56041  ChIJR4w4T5CnUYcRvTPRgMmXumM     Q483973    geoId/56041
# 22840  US_WY_56043  ChIJIXR5_L9BS1MRLvs8KUxeZC8     Q112846    geoId/56043
# 22841  US_WY_56045  ChIJd4Rqhed3YocR7ubT5-HgoJg     Q115413    geoId/56045
#
#       country_code              country_name subregion1_code subregion1_name  \
# 19557           US  United States of America             NaN             NaN
# 19558           US  United States of America              AK          Alaska
# 19559           US  United States of America              AK          Alaska
# 19560           US  United States of America              AK          Alaska
# 19561           US  United States of America              AK          Alaska
# ...            ...                       ...             ...             ...
# 22837           US  United States of America              WY         Wyoming
# 22838           US  United States of America              WY         Wyoming
# 22839           US  United States of America              WY         Wyoming
# 22840           US  United States of America              WY         Wyoming
# 22841           US  United States of America              WY         Wyoming
#
#       subregion2_code         subregion2_name locality_code locality_name  \
# 19557             NaN                     NaN           NaN           NaN
# 19558             NaN                     NaN           NaN           NaN
# 19559           02013          Aleutians East           NaN           NaN
# 19560           02016          Aleutians West           NaN           NaN
# 19561           02020  Anchorage Municipality           NaN           NaN
# ...               ...                     ...           ...           ...
# 22837           56037       Sweetwater County           NaN           NaN
# 22838           56039            Teton County           NaN           NaN
# 22839           56041            Uinta County           NaN           NaN
# 22840           56043         Washakie County           NaN           NaN
# 22841           56045           Weston County           NaN           NaN
#
#       iso_3166_1_alpha_2 iso_3166_1_alpha_3  aggregation_level
# 19557                 US                USA                  0
# 19558                 US                USA                  1
# 19559                 US                USA                  2
# 19560                 US                USA                  2
# 19561                 US                USA                  2
# ...                  ...                ...                ...
# 22837                 US                USA                  2
# 22838                 US                USA                  2
# 22839                 US                USA                  2
# 22840                 US                USA                  2
# 22841                 US                USA                  2
#
# [3285 rows x 15 columns]

# %%
# get the US data
us_epi_df = epi_df.loc[epi_df['location_key'] == 'US']
us_vac_df = vac_df.loc[vac_df['location_key'] == 'US']

# %%
us_ev_df = us_epi_df.merge(us_vac_df, on='date', how='inner')
us_ev_df
# Out:
#            date location_key_x  new_confirmed  new_deceased  new_recovered  \
# 0    2020-12-13             US       177830.0        2021.0            NaN
# 1    2020-12-14             US       195630.0        1996.0            NaN
# 2    2020-12-15             US       197440.0        2724.0            NaN
# 3    2020-12-16             US       237037.0        3374.0            NaN
# 4    2020-12-17             US       242528.0        3316.0            NaN
# ..          ...            ...            ...           ...            ...
# 636  2022-09-10             US        19715.0          51.0            NaN
# 637  2022-09-11             US        16742.0          10.0            NaN
# 638  2022-09-12             US        60728.0         213.0            NaN
# 639  2022-09-13             US        54413.0         460.0            NaN
# 640  2022-09-14             US        83403.0         705.0            NaN
#
#      new_tested  cumulative_confirmed  cumulative_deceased  \
# 0     1495092.0            16119805.0             287276.0
# 1     1946701.0            16315435.0             289272.0
# 2     2078178.0            16512875.0             291996.0
# 3     2053475.0            16749912.0             295370.0
# 4     2022937.0            16992440.0             298686.0
# ..          ...                   ...                  ...
# 636         NaN            92225201.0            1003766.0
# 637         NaN            92241943.0            1003776.0
# 638         NaN            92302671.0            1003989.0
# 639         NaN            92357092.0            1004449.0
# 640         NaN            92440495.0            1005195.0
#
#      cumulative_recovered  cumulative_tested  ...  \
# 0                     NaN        228772064.0  ...
# 1                     NaN        230718765.0  ...
# 2                     NaN        232796943.0  ...
# 3                     NaN        234850418.0  ...
# 4                     NaN        236873355.0  ...
# ..                    ...                ...  ...
# 636                   NaN                NaN  ...
# 637                   NaN                NaN  ...
# 638                   NaN                NaN  ...
# 639                   NaN                NaN  ...
# 640                   NaN                NaN  ...
#
#     new_persons_fully_vaccinated_janssen  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ..                                   ...
# 636                                  0.0
# 637                                  0.0
# 638                                  0.0
# 639                                  0.0
# 640                                  0.0
#
#      cumulative_persons_fully_vaccinated_janssen  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ..                                           ...
# 636                                   17094523.0
# 637                                   17094523.0
# 638                                   17094523.0
# 639                                   17094523.0
# 640                                   17094523.0
#
#      new_vaccine_doses_administered_janssen  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ..                                      ...
# 636                                     0.0
# 637                                     0.0
# 638                                     0.0
# 639                                     0.0
# 640                                     0.0
#
#      cumulative_vaccine_doses_administered_janssen  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ..                                             ...
# 636                                     18881650.0
# 637                                     18881650.0
# 638                                     18881650.0
# 639                                     18881650.0
# 640                                     18881650.0
#
#      new_persons_vaccinated_sinovac  total_persons_vaccinated_sinovac  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
# ..                              ...                               ...
# 636                             NaN                               NaN
# 637                             NaN                               NaN
# 638                             NaN                               NaN
# 639                             NaN                               NaN
# 640                             NaN                               NaN
#
#      new_persons_fully_vaccinated_sinovac  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ..                                    ...
# 636                                   NaN
# 637                                   NaN
# 638                                   NaN
# 639                                   NaN
# 640                                   NaN
#
#      total_persons_fully_vaccinated_sinovac  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ..                                      ...
# 636                                     NaN
# 637                                     NaN
# 638                                     NaN
# 639                                     NaN
# 640                                     NaN
#
#      new_vaccine_doses_administered_sinovac  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ..                                      ...
# 636                                     NaN
# 637                                     NaN
# 638                                     NaN
# 639                                     NaN
# 640                                     NaN
#
#      total_vaccine_doses_administered_sinovac
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 636                                       NaN
# 637                                       NaN
# 638                                       NaN
# 639                                       NaN
# 640                                       NaN
#
# [641 rows x 41 columns]

# %%
# convert data to sliding window

cases = pd.DataFrame(us_ev_df['new_confirmed'])
cols = list()
cols.append(cases.shift(1))
cols.append(cases)
cases_new = pd.concat(cols, axis=1)
cases_new = cases_new.set_axis(['before', 'after'], axis=1)
cases_new = cases_new.tail(-1)
cases_sw = np.array(cases_new)
cases_new
# Out:
#        before     after
# 1    177830.0  195630.0
# 2    195630.0  197440.0
# 3    197440.0  237037.0
# 4    237037.0  242528.0
# 5    242528.0  233736.0
# ..        ...       ...
# 636   81861.0   19715.0
# 637   19715.0   16742.0
# 638   16742.0   60728.0
# 639   60728.0   54413.0
# 640   54413.0   83403.0
#
# [640 rows x 2 columns]

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.svm import LinearSVR

def update_model(train, testX):
    model = RandomForestRegressor(n_estimators=1000)
    model.fit(train[:, :-1], train[:, -1])
    y_pred = model.predict([testX])
    return y_pred[0]

def update_svm(train, testX):
    model = LinearSVR(max_iter=100000)
    model.fit(train[:, :-1], train[:, -1])
    y_pred = model.predict([testX])
    return y_pred[0]

def train_test_split(data, n_test):
 return data[:-n_test, :], data[-n_test:, :]

# %%
cases_sw = np.array(cases_new)
train, test = train_test_split(cases_sw, int(0.25*len(cases_sw)))
pred = list()
for i in range(len(test)):
    y_pred = update_svm(train, test[i, :-1])
    pred.append(y_pred)
    train = np.vstack([train, test[i]])
mse = mean_squared_error(test[:, -1], pred)
print(mse)

plt.plot(range(len(pred)), pred, label='predicted')
plt.plot(range(len(test)), test[:, -1], label='actual')
plt.xlabel('time')
plt.ylabel('new cases')
plt.title('Predicting New Cases Over Time with SVM, 25% Test Size')
plt.legend()
plt.show()
# Out:
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 3325255522.0244946
# c:\Users\eshwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %%
import warnings
warnings.filterwarnings("ignore")

cases_sw = np.array(cases_new)
error = list()
for i in range(21):
    train, test = train_test_split(cases_sw, int((0.2+i/100) * len(cases_sw)))
    pred = list()
    for i in range(len(test)):
        y_pred = update_svm(train, test[i, :-1])
        pred.append(y_pred)
        train = np.vstack([train, test[i]])
    mse = mean_squared_error(test[:, -1], pred)
    error.append(mse)

plt.plot(range(20, 41, 1), error)
plt.xlabel('test size')
plt.ylabel('mean squared error')
plt.title('Mean Squared Error vs Test Dataset Size for SVM')
plt.show()

# %%
cases_sw = np.array(cases_new)
train, test = train_test_split(cases_sw, int(0.34*len(cases_sw)))
pred = list()
for i in range(len(test)):
    y_pred = update_model(train, test[i, :-1])
    pred.append(y_pred)
    train = np.vstack([train, test[i]])
mse = mean_squared_error(test[:, -1], pred)
print(mse)

plt.plot(range(len(pred)), pred, label='predicted')
plt.plot(range(len(test)), test[:, -1], label='actual')
plt.xlabel('time')
plt.ylabel('new cases')
plt.title('Predicting New Cases Over Time, 34% Test Size')
plt.legend()
plt.show()
# Out:
# 2864141505.112668

# %%
plt.plot(range(len(pred)), pred, label='predicted')
plt.plot(range(len(test)), test[:, -1], label='actual')
plt.xlabel('time')
plt.ylabel('new cases')
plt.title('Predicting New Cases Over Time, 20% Test Size')
plt.legend()
plt.show()

# %%
cases_sw = np.array(cases_new)
error = list()
for i in range(31):
    train, test = train_test_split(cases_sw, int((0.2+i/100) * len(cases_sw)))
    pred = list()
    for i in range(len(test)):
        y_pred = update_model(train, test[i, :-1])
        pred.append(y_pred)
        train = np.vstack([train, test[i]])
    mse = mean_squared_error(test[:, -1], pred)
    error.append(mse)

plt.plot(range(20, 51, 1), error)
plt.xlabel('test size')
plt.ylabel('mean squared error')
plt.title('Mean Squared Error vs Test Dataset Size')
plt.show()
